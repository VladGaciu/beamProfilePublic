# %%
import os
import tensorflow as tf
import numpy as np
from itertools import cycle
from PIL import Image

import time

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import roc_auc_score

from numpy import argmax, array
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras.models import Sequential

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import callbacks
from keras.metrics import top_k_categorical_accuracy
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.utils import plot_model
from keras.metrics import top_k_categorical_accuracy

from keras.layers.convolutional import Conv2DTranspose , Conv2D
# Out:
# 2023-07-26 14:20:29.995223: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-26 14:20:30.357788: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-07-26 14:20:31.268473: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/vlad/root/lib:/home/vlad/anaconda3/lib/:/home/vlad/anaconda3/lib/python3.9/site-packages/nvidia/cudnn/lib
# 2023-07-26 14:20:31.268559: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/vlad/root/lib:/home/vlad/anaconda3/lib/:/home/vlad/anaconda3/lib/python3.9/site-packages/nvidia/cudnn/lib
# 2023-07-26 14:20:31.268565: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /home/vlad/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 2023-07-26 14:20:33.152059: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-26 14:20:33.281660: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-26 14:20:33.282817: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-26 14:20:33.285087: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-26 14:20:33.286223: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-26 14:20:33.287324: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-26 14:20:33.288265: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-26 14:20:34.290786: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-26 14:20:34.292675: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-26 14:20:34.294064: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-26 14:20:34.295109: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4765 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:09:00.0, compute capability: 8.6
# 1 Physical GPUs, 1 Logical GPUs

# %%
train_data_dir='/home/vlad/Desktop/train_2/'
validate_data_dir='/home/vlad/Desktop/allimages_2/'
test_data_dir='/home/vlad/Desktop/test_2/'

# %%
# Define Constants
img_height = 100
img_width = 100

batch_size_train=200
batch_size_test=100
epochs=200

# %%
input_shape = (img_width, img_height, 1)

# %%
# Train Datagen
print("\nInitializing Training Data Generator:")
train_datagen = ImageDataGenerator(
                                rescale=1. / 255,
                                #width_shift_range=2,
                                #height_shift_range=2,
                                #rotation_range=45,
                                #shear_range=1,
                                zoom_range=1,
                                featurewise_std_normalization=True)
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size_train,
    color_mode="grayscale",
    class_mode='categorical')
print("")

# Validation Datagen
print("Initializing Validation Data Generator:")
validation_datagen = ImageDataGenerator(
                                rescale=1. / 255,
                                #width_shift_range=2,
                                #height_shift_range=2,
                                #rotation_range=45,
                                #shear_range=1,
                                zoom_range=1,
                                featurewise_std_normalization=True)
valid_generator = validation_datagen.flow_from_directory(
    validate_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size_test,
    color_mode="grayscale",
    class_mode='categorical')
print("")

# Test Datagen
print("Initializing Test Data Generator:")
test_datagen = ImageDataGenerator(
                                rescale=1. / 255,
                                #width_shift_range=2,
                                #height_shift_range=2, 
                                #rotation_range=45,
                                #shear_range=1,
                                zoom_range=1,
                                featurewise_std_normalization=True)
test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size_test,
    color_mode="grayscale",
    class_mode='categorical')
print("")
# Out:
# Initializing Training Data Generator:
# Found 8760 images belonging to 1 classes.
#
# Initializing Validation Data Generator:
# Found 1459 images belonging to 1 classes.
#
# Initializing Test Data Generator:
# Found 4380 images belonging to 1 classes.
# /home/vlad/anaconda3/lib/python3.9/site-packages/keras/preprocessing/image.py:1462: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, which overrides setting of `featurewise_center`.
#   warnings.warn(

# %%
#create model
model = Sequential()

#Encoder
model.add(Conv2D(16, (2, 2), input_shape=input_shape))
model.add(Activation('linear'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(8, (2, 2)))
model.add(Activation('linear'))
model.add(MaxPooling2D(pool_size=(3, 3)))

#Decoder

model.add(Conv2DTranspose(8, (3, 3)))
model.add(Activation('linear'))
#model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2DTranspose(16, (10, 10)))
model.add(Activation('linear'))
#model.add(MaxPooling2D(pool_size=(2, 2)))

#Bottleneck

model.add(Conv2D(1, (4, 4)))
model.add(Activation('linear'))

#Output
model.add(Flatten())
model.add(Dense(9))
model.add(Activation('relu'))
model.add(Dense(3, activation='softmax'))

output = model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 99, 99, 16)        80
#
#  activation (Activation)     (None, 99, 99, 16)        0
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 8)         520
#
#  activation_1 (Activation)   (None, 48, 48, 8)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 8)        0
#  2D)
#
#  conv2d_transpose (Conv2DTra  (None, 18, 18, 8)        584
#  nspose)
#
#  activation_2 (Activation)   (None, 18, 18, 8)         0
#
#  conv2d_transpose_1 (Conv2DT  (None, 27, 27, 16)       12816
#  ranspose)
#
#  activation_3 (Activation)   (None, 27, 27, 16)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 1)         257
#
#  activation_4 (Activation)   (None, 24, 24, 1)         0
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 9)                 5193
#
#  activation_5 (Activation)   (None, 9)                 0
#
#  dense_1 (Dense)             (None, 3)                 30
#
# =================================================================
# Total params: 19,480
# Trainable params: 19,480
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compile model
#num_classes = 3

#def top_3_categorical_accuracy(y_true, y_pred):
#    return top_k_categorical_accuracy(y_true, y_pred, k=10)

model.compile(optimizer = tf.optimizers.SGD(learning_rate=0.00001),
              loss = 'SparseCategoricalCrossentropy',
              metrics = ['SparseCategoricalAccuracy'])

# %%
earlystopping = callbacks.EarlyStopping(monitor='val_sparse_categorical_accuracy', 
                                        mode='max', 
                                        patience=5, 
                                        restore_best_weights=True)

# %%
#fit model
print("Starting Training...")
history = model.fit(
        train_generator,
        steps_per_epoch=40,
        epochs=epochs,
        validation_data=test_generator,
        validation_steps=40,
        callbacks =[earlystopping],
        shuffle=True)
print("Done!\n\n")
# Out:
# Starting Training...
# /home/vlad/anaconda3/lib/python3.9/site-packages/keras/preprocessing/image.py:1863: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn(
# /home/vlad/anaconda3/lib/python3.9/site-packages/keras/preprocessing/image.py:1873: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn(
# Epoch 1/200
# 2023-07-26 14:20:37.438446: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8600
#  1/40 [..............................] - ETA: 3:02 - loss: 1.1084 - sparse_categorical_accuracy: 0.1750
# 2023-07-26 14:20:39.543282: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 40/40 [==============================] - 16s 288ms/step - loss: 1.1131 - sparse_categorical_accuracy: 0.1773 - val_loss: 1.1108 - val_sparse_categorical_accuracy: 0.2058
# Epoch 2/200
# 40/40 [==============================] - 10s 252ms/step - loss: 1.1094 - sparse_categorical_accuracy: 0.2180 - val_loss: 1.1078 - val_sparse_categorical_accuracy: 0.2412
# Epoch 3/200
# 40/40 [==============================] - 10s 245ms/step - loss: 1.1058 - sparse_categorical_accuracy: 0.2521 - val_loss: 1.1042 - val_sparse_categorical_accuracy: 0.2738
# Epoch 4/200
# 40/40 [==============================] - 10s 255ms/step - loss: 1.1040 - sparse_categorical_accuracy: 0.2786 - val_loss: 1.1015 - val_sparse_categorical_accuracy: 0.3095
# Epoch 5/200
# 40/40 [==============================] - 10s 247ms/step - loss: 1.0998 - sparse_categorical_accuracy: 0.3259 - val_loss: 1.0992 - val_sparse_categorical_accuracy: 0.3510
# Epoch 6/200
# 40/40 [==============================] - 10s 243ms/step - loss: 1.0980 - sparse_categorical_accuracy: 0.3492 - val_loss: 1.0962 - val_sparse_categorical_accuracy: 0.3795
# Epoch 7/200
# 40/40 [==============================] - 10s 247ms/step - loss: 1.0935 - sparse_categorical_accuracy: 0.3946 - val_loss: 1.0928 - val_sparse_categorical_accuracy: 0.4103
# Epoch 8/200
# 40/40 [==============================] - 10s 245ms/step - loss: 1.0915 - sparse_categorical_accuracy: 0.4320 - val_loss: 1.0911 - val_sparse_categorical_accuracy: 0.4455
# Epoch 9/200
# 40/40 [==============================] - 10s 249ms/step - loss: 1.0892 - sparse_categorical_accuracy: 0.4546 - val_loss: 1.0879 - val_sparse_categorical_accuracy: 0.4667
# Epoch 10/200
# 40/40 [==============================] - 10s 247ms/step - loss: 1.0867 - sparse_categorical_accuracy: 0.4781 - val_loss: 1.0853 - val_sparse_categorical_accuracy: 0.4918
# Epoch 11/200
# 40/40 [==============================] - 10s 241ms/step - loss: 1.0838 - sparse_categorical_accuracy: 0.5156 - val_loss: 1.0820 - val_sparse_categorical_accuracy: 0.5365
# Epoch 12/200
# 40/40 [==============================] - 10s 240ms/step - loss: 1.0817 - sparse_categorical_accuracy: 0.5361 - val_loss: 1.0785 - val_sparse_categorical_accuracy: 0.5665
# Epoch 13/200
# 40/40 [==============================] - 10s 249ms/step - loss: 1.0785 - sparse_categorical_accuracy: 0.5650 - val_loss: 1.0776 - val_sparse_categorical_accuracy: 0.5805
# Epoch 14/200
# 40/40 [==============================] - 10s 246ms/step - loss: 1.0758 - sparse_categorical_accuracy: 0.5912 - val_loss: 1.0758 - val_sparse_categorical_accuracy: 0.6155
# Epoch 15/200
# 40/40 [==============================] - 10s 245ms/step - loss: 1.0748 - sparse_categorical_accuracy: 0.6202 - val_loss: 1.0720 - val_sparse_categorical_accuracy: 0.6525
# Epoch 16/200
# 40/40 [==============================] - 10s 255ms/step - loss: 1.0716 - sparse_categorical_accuracy: 0.6514 - val_loss: 1.0703 - val_sparse_categorical_accuracy: 0.6637
# Epoch 17/200
# 40/40 [==============================] - 10s 245ms/step - loss: 1.0691 - sparse_categorical_accuracy: 0.6783 - val_loss: 1.0677 - val_sparse_categorical_accuracy: 0.6890
# Epoch 18/200
# 40/40 [==============================] - 10s 247ms/step - loss: 1.0656 - sparse_categorical_accuracy: 0.7124 - val_loss: 1.0646 - val_sparse_categorical_accuracy: 0.7170
# Epoch 19/200
# 40/40 [==============================] - 10s 243ms/step - loss: 1.0638 - sparse_categorical_accuracy: 0.7367 - val_loss: 1.0619 - val_sparse_categorical_accuracy: 0.7502
# Epoch 20/200
# 40/40 [==============================] - 10s 250ms/step - loss: 1.0609 - sparse_categorical_accuracy: 0.7564 - val_loss: 1.0602 - val_sparse_categorical_accuracy: 0.7655
# Epoch 21/200
# 40/40 [==============================] - 10s 253ms/step - loss: 1.0577 - sparse_categorical_accuracy: 0.7829 - val_loss: 1.0563 - val_sparse_categorical_accuracy: 0.7930
# Epoch 22/200
# 40/40 [==============================] - 10s 249ms/step - loss: 1.0558 - sparse_categorical_accuracy: 0.7969 - val_loss: 1.0558 - val_sparse_categorical_accuracy: 0.8052
# Epoch 23/200
# 40/40 [==============================] - 10s 249ms/step - loss: 1.0526 - sparse_categorical_accuracy: 0.8215 - val_loss: 1.0515 - val_sparse_categorical_accuracy: 0.8353
# Epoch 24/200
# 40/40 [==============================] - 10s 260ms/step - loss: 1.0517 - sparse_categorical_accuracy: 0.8249 - val_loss: 1.0483 - val_sparse_categorical_accuracy: 0.8490
# Epoch 25/200
# 40/40 [==============================] - 10s 252ms/step - loss: 1.0470 - sparse_categorical_accuracy: 0.8526 - val_loss: 1.0472 - val_sparse_categorical_accuracy: 0.8480
# Epoch 26/200
# 40/40 [==============================] - 10s 245ms/step - loss: 1.0454 - sparse_categorical_accuracy: 0.8595 - val_loss: 1.0422 - val_sparse_categorical_accuracy: 0.8725
# Epoch 27/200
# 40/40 [==============================] - 10s 248ms/step - loss: 1.0424 - sparse_categorical_accuracy: 0.8668 - val_loss: 1.0422 - val_sparse_categorical_accuracy: 0.8645
# Epoch 28/200
# 40/40 [==============================] - 10s 250ms/step - loss: 1.0393 - sparse_categorical_accuracy: 0.8790 - val_loss: 1.0374 - val_sparse_categorical_accuracy: 0.8892
# Epoch 29/200
# 40/40 [==============================] - 10s 255ms/step - loss: 1.0377 - sparse_categorical_accuracy: 0.8799 - val_loss: 1.0351 - val_sparse_categorical_accuracy: 0.8980
# Epoch 30/200
# 40/40 [==============================] - 10s 261ms/step - loss: 1.0344 - sparse_categorical_accuracy: 0.8854 - val_loss: 1.0336 - val_sparse_categorical_accuracy: 0.8920
# Epoch 31/200
# 40/40 [==============================] - 10s 253ms/step - loss: 1.0313 - sparse_categorical_accuracy: 0.9014 - val_loss: 1.0306 - val_sparse_categorical_accuracy: 0.9095
# Epoch 32/200
# 40/40 [==============================] - 10s 248ms/step - loss: 1.0285 - sparse_categorical_accuracy: 0.9058 - val_loss: 1.0280 - val_sparse_categorical_accuracy: 0.9068
# Epoch 33/200
# 40/40 [==============================] - 10s 246ms/step - loss: 1.0252 - sparse_categorical_accuracy: 0.9160 - val_loss: 1.0248 - val_sparse_categorical_accuracy: 0.9183
# Epoch 34/200
# 40/40 [==============================] - 10s 249ms/step - loss: 1.0226 - sparse_categorical_accuracy: 0.9210 - val_loss: 1.0216 - val_sparse_categorical_accuracy: 0.9243
# Epoch 35/200
# 40/40 [==============================] - 10s 246ms/step - loss: 1.0199 - sparse_categorical_accuracy: 0.9251 - val_loss: 1.0196 - val_sparse_categorical_accuracy: 0.9262
# Epoch 36/200
# 40/40 [==============================] - 10s 249ms/step - loss: 1.0173 - sparse_categorical_accuracy: 0.9307 - val_loss: 1.0161 - val_sparse_categorical_accuracy: 0.9310
# Epoch 37/200
# 40/40 [==============================] - 10s 255ms/step - loss: 1.0145 - sparse_categorical_accuracy: 0.9307 - val_loss: 1.0134 - val_sparse_categorical_accuracy: 0.9350
# Epoch 38/200
# 40/40 [==============================] - 10s 258ms/step - loss: 1.0104 - sparse_categorical_accuracy: 0.9388 - val_loss: 1.0098 - val_sparse_categorical_accuracy: 0.9442
# Epoch 39/200
# 40/40 [==============================] - 10s 248ms/step - loss: 1.0082 - sparse_categorical_accuracy: 0.9426 - val_loss: 1.0070 - val_sparse_categorical_accuracy: 0.9495
# Epoch 40/200
# 40/40 [==============================] - 10s 248ms/step - loss: 1.0052 - sparse_categorical_accuracy: 0.9472 - val_loss: 1.0032 - val_sparse_categorical_accuracy: 0.9545
# Epoch 41/200
# 40/40 [==============================] - 10s 254ms/step - loss: 1.0018 - sparse_categorical_accuracy: 0.9517 - val_loss: 0.9995 - val_sparse_categorical_accuracy: 0.9532
# Epoch 42/200
# 40/40 [==============================] - 10s 252ms/step - loss: 0.9980 - sparse_categorical_accuracy: 0.9554 - val_loss: 0.9969 - val_sparse_categorical_accuracy: 0.9610
# Epoch 43/200
# 40/40 [==============================] - 10s 246ms/step - loss: 0.9945 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.9937 - val_sparse_categorical_accuracy: 0.9625
# Epoch 44/200
# 40/40 [==============================] - 10s 246ms/step - loss: 0.9916 - sparse_categorical_accuracy: 0.9612 - val_loss: 0.9901 - val_sparse_categorical_accuracy: 0.9660
# Epoch 45/200
# 40/40 [==============================] - 10s 248ms/step - loss: 0.9878 - sparse_categorical_accuracy: 0.9634 - val_loss: 0.9861 - val_sparse_categorical_accuracy: 0.9728
# Epoch 46/200
# 40/40 [==============================] - 10s 247ms/step - loss: 0.9835 - sparse_categorical_accuracy: 0.9717 - val_loss: 0.9837 - val_sparse_categorical_accuracy: 0.9670
# Epoch 47/200
# 40/40 [==============================] - 10s 248ms/step - loss: 0.9806 - sparse_categorical_accuracy: 0.9754 - val_loss: 0.9792 - val_sparse_categorical_accuracy: 0.9785
# Epoch 48/200
# 40/40 [==============================] - 10s 253ms/step - loss: 0.9761 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.9743 - val_sparse_categorical_accuracy: 0.9820
# Epoch 49/200
# 40/40 [==============================] - 10s 256ms/step - loss: 0.9724 - sparse_categorical_accuracy: 0.9808 - val_loss: 0.9708 - val_sparse_categorical_accuracy: 0.9858
# Epoch 50/200
# 40/40 [==============================] - 10s 252ms/step - loss: 0.9685 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.9660 - val_sparse_categorical_accuracy: 0.9885
# Epoch 51/200
# 40/40 [==============================] - 10s 246ms/step - loss: 0.9643 - sparse_categorical_accuracy: 0.9915 - val_loss: 0.9629 - val_sparse_categorical_accuracy: 0.9927
# Epoch 52/200
# 40/40 [==============================] - 10s 255ms/step - loss: 0.9590 - sparse_categorical_accuracy: 0.9920 - val_loss: 0.9577 - val_sparse_categorical_accuracy: 0.9927
# Epoch 53/200
# 40/40 [==============================] - 10s 256ms/step - loss: 0.9550 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.9537 - val_sparse_categorical_accuracy: 0.9955
# Epoch 54/200
# 40/40 [==============================] - 10s 258ms/step - loss: 0.9501 - sparse_categorical_accuracy: 0.9947 - val_loss: 0.9482 - val_sparse_categorical_accuracy: 0.9960
# Epoch 55/200
# 40/40 [==============================] - 10s 256ms/step - loss: 0.9454 - sparse_categorical_accuracy: 0.9952 - val_loss: 0.9447 - val_sparse_categorical_accuracy: 0.9965
# Epoch 56/200
# 40/40 [==============================] - 10s 255ms/step - loss: 0.9406 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.9387 - val_sparse_categorical_accuracy: 0.9975
# Epoch 57/200
# 40/40 [==============================] - 10s 248ms/step - loss: 0.9356 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.9352 - val_sparse_categorical_accuracy: 0.9970
# Epoch 58/200
# 40/40 [==============================] - 10s 246ms/step - loss: 0.9303 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.9284 - val_sparse_categorical_accuracy: 0.9992
# Epoch 59/200
# 40/40 [==============================] - 11s 270ms/step - loss: 0.9248 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.9230 - val_sparse_categorical_accuracy: 0.9987
# Epoch 60/200
# 40/40 [==============================] - 11s 268ms/step - loss: 0.9195 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.9180 - val_sparse_categorical_accuracy: 0.9990
# Epoch 61/200
# 40/40 [==============================] - 11s 269ms/step - loss: 0.9141 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.9115 - val_sparse_categorical_accuracy: 0.9998
# Epoch 62/200
# 40/40 [==============================] - 11s 280ms/step - loss: 0.9080 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.9055 - val_sparse_categorical_accuracy: 0.9998
# Epoch 63/200
# 40/40 [==============================] - 11s 271ms/step - loss: 0.9019 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.8999 - val_sparse_categorical_accuracy: 1.0000
# Epoch 64/200
# 40/40 [==============================] - 10s 257ms/step - loss: 0.8956 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8933 - val_sparse_categorical_accuracy: 1.0000
# Epoch 65/200
# 40/40 [==============================] - 10s 255ms/step - loss: 0.8893 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8875 - val_sparse_categorical_accuracy: 1.0000
# Epoch 66/200
# 40/40 [==============================] - 10s 245ms/step - loss: 0.8827 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8804 - val_sparse_categorical_accuracy: 1.0000
# Epoch 67/200
# 40/40 [==============================] - 10s 246ms/step - loss: 0.8762 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8726 - val_sparse_categorical_accuracy: 1.0000
# Epoch 68/200
# 40/40 [==============================] - 10s 259ms/step - loss: 0.8687 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8669 - val_sparse_categorical_accuracy: 1.0000
# Done!

# %%
def plot_hist(hist):
    plt.plot(hist.history['sparse_categorical_accuracy'])
    plt.plot(hist.history['val_sparse_categorical_accuracy'])
    plt.title('CategoricalCrossentropy')
    plt.ylabel('sparse_categorical_accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

plot_hist(history)

# %%
model.evaluate(test_generator)
# Out:
# 44/44 [==============================] - 4s 86ms/step - loss: 0.8998 - sparse_categorical_accuracy: 0.9998
# [0.8998215794563293, 0.9997717142105103]

# %%
path = '/home/vlad/Desktop/allimages/1/'
dirList = os.listdir(path)
plt.figure(figsize=(12,20))
count = 0
imageList = []
label = 'Low Confidence'

one = 0
two = 0
three = 0

for i in dirList[:]:
    #print(i)
    image = Image.open(path + str(i))
    #plt.figure()
    #plt.imshow(image)
    #print(f"Original size : {image.size}")
        
    image = image.resize((img_width, img_height))
    #print(f"New size : {image.size}")

    x = np.asarray(image)   
    x = np.expand_dims(x, axis=0)
    #print(x/255.0)
    images = np.vstack([x])
    #print(images[0][50])
    classes = model.predict(
    images,
    batch_size=1,
    verbose='off',
    steps=None,
    callbacks=None,
    max_queue_size=10,
    workers=1,
    use_multiprocessing=True)

    classifier = "  Low Confidence"
    
    score = float(classes[0][0])
    #print(f"   This image is {100 * (score):.2f}% far-field.")
    if score > 0.66:
        classifier = f"{100 * (score):.2f}%  far-field"
        label = ['far-field']
        one += 1
   
    score = float(classes[0][1])
    #print(f"   This image is {100 * (score):.2f}% wedge.")
    if score > 0.66:
        classifier = f"{100 * (score):.2f}%  near-field"
        label = ['near-field']
        two += 1
    
    score = float(classes[0][2])
    #print(f"   This image is {100 * (score):.2f}% near-field.")
    if score > 0.66:
        classifier= f"{100 * (score):.2f}%  wedge"
        label = ['wedge']
        three += 1
    
    imageList += label
    
    
    if classifier == "  Low Confidence":
        classifier = f"{100 * (classes[0].max()):.2f}% Low Conf."
        
    if count < 60:
        ax=plt.subplot(10,6,count+1)
        plt.imshow(image, cmap='gray')
        plt.title(str(i[0:6] + "   " + classifier), fontsize = 7)
        count += 1
        plt.axis('off')
print("Example Predicted Set:\n\n")
# Out:
# Example Predicted Set:

# %%
nameList = []
index = 0
while index < len(dirList[:]):
    if dirList[index][0:3] == 'B12':
        nameList += ['near-field']
    elif dirList[index][0:3] == 'B11':
        nameList += ['wedge']
    elif dirList[index][0:4] == 'ATW1':
        nameList += ['near-field']
    elif dirList[index][0:5] == 'FE2_C':
        nameList += ['wedge']
    elif dirList[index][0:5] == 'FE2_S':
        nameList += ['near-field']
    elif dirList[index][0:4] == 'BTW1':
        nameList += ['near-field']
    elif dirList[index][0:3] == 'A12':
        nameList += ['near-field']
    elif dirList[index][0:4] == 'ATW2':
        nameList += ['far-field']
    else:
        nameList += ['far-field']
    index += 1

# %%
from sklearn.metrics import confusion_matrix

y_true = nameList
y_pred = imageList
confusion_matrix(y_true, y_pred)
# Out:
# array([[186, 117,   4],
#        [  0, 819,   0],
#        [  0, 179, 154]])

# %%
from sklearn.metrics import ConfusionMatrixDisplay
cm = confusion_matrix(y_true, y_pred)

farTrue=cm[0][0]+cm[1][0]+cm[2][0]
nearTrue=cm[0][1]+cm[1][1]+cm[2][1]
wedgeTrue=cm[0][2]++cm[1][2]+cm[2][2]

correctValue = cm[0][0]+cm[1][1]+cm[2][2]

print(f"High Confidence Images: {100*(one+two+three)/(index):.2f} % of total (greater than 66% confidence value).")
print("\n")

print(f"{(one)}/{(farTrue)} far-field predictions: 2-")
print(f"{(two)}/{(nearTrue)} far-field predictions: 0-")
print(f"{(three)}/{(wedgeTrue)} wedge predictions: 1-")


print("\n")
print(f"{correctValue} values correct out of {index}: {100 * (correctValue/index):.2f}% model accuracy")
cm_display = ConfusionMatrixDisplay(cm).plot()
# Out:
# High Confidence Images: 99.11 % of total (greater than 66% confidence value).
#
#
# 186/186 far-field predictions: 2-
# 1105/1115 far-field predictions: 0-
# 155/158 wedge predictions: 1-
#
#
# 1159 values correct out of 1459: 79.44% model accuracy
